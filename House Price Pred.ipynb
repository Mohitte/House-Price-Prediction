# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\MOHIT TARADE'

# %%
import pandas as pd
import numpy as np
# Out:
# C:\Users\MOHIT TARADE\New folder\Lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
df=pd.read_csv(r'USA_Housing1.csv')

# %%
df
# Out:
#       Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0          79545.45857             5.682861                   7.009188
# 1          79248.64245             6.002900                   6.730821
# 2          61287.06718             5.865890                   8.512727
# 3          63345.24005             7.188236                   5.586729
# 4          59982.19723             5.040555                   7.839388
# ...                ...                  ...                        ...
# 4995       60567.94414             7.830362                   6.137356
# 4996       78491.27543             6.999135                   6.576763
# 4997       63390.68689             7.250591                   4.805081
# 4998       68001.33124             5.534388                   7.130144
# 4999       65510.58180             5.992305                   6.792336
#
#       Avg. Area Number of Bedrooms  Area Population         Price  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 7 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Avg. Area Income              5000 non-null   float64
#  1   Avg. Area House Age           5000 non-null   float64
#  2   Avg. Area Number of Rooms     5000 non-null   float64
#  3   Avg. Area Number of Bedrooms  5000 non-null   float64
#  4   Area Population               5000 non-null   float64
#  5   Price                         5000 non-null   float64
#  6   Address                       5000 non-null   object
# dtypes: float64(6), object(1)
# memory usage: 273.6+ KB

# %%
df.describe()
# Out:
#        Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# count       5000.000000          5000.000000                5000.000000
# mean       68583.108984             5.977222                   6.987792
# std        10657.991214             0.991456                   1.005833
# min        17796.631190             2.644304                   3.236194
# 25%        61480.562390             5.322283                   6.299250
# 50%        68804.286405             5.970429                   7.002902
# 75%        75783.338665             6.650808                   7.665871
# max       107701.748400             9.519088                  10.759588
#
#        Avg. Area Number of Bedrooms  Area Population         Price
# count                   5000.000000      5000.000000  5.000000e+03
# mean                       3.981330     36163.516039  1.232073e+06
# std                        1.234137      9925.650114  3.531176e+05
# ...

# %%
df.isnull().sum()
# Out:
# Avg. Area Income                0
# Avg. Area House Age             0
# Avg. Area Number of Rooms       0
# Avg. Area Number of Bedrooms    0
# Area Population                 0
# Price                           0
# Address                         0
# dtype: int64

# %%
df.round()
# Out:
#       Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0              79545.0                  6.0                        7.0
# 1              79249.0                  6.0                        7.0
# 2              61287.0                  6.0                        9.0
# 3              63345.0                  7.0                        6.0
# 4              59982.0                  5.0                        8.0
# ...                ...                  ...                        ...
# 4995           60568.0                  8.0                        6.0
# 4996           78491.0                  7.0                        7.0
# 4997           63391.0                  7.0                        5.0
# 4998           68001.0                  6.0                        7.0
# 4999           65511.0                  6.0                        7.0
#
#       Avg. Area Number of Bedrooms  Area Population      Price  \
# ...

# %%
df['Avg. Area Income'].astype('int')
# Out:
# 0       79545
# 1       79248
# 2       61287
# 3       63345
# 4       59982
#         ...
# 4995    60567
# 4996    78491
# 4997    63390
# 4998    68001
# 4999    65510
# Name: Avg. Area Income, Length: 5000, dtype: int32

# %%
df
# Out:
#       Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0          79545.45857             5.682861                   7.009188
# 1          79248.64245             6.002900                   6.730821
# 2          61287.06718             5.865890                   8.512727
# 3          63345.24005             7.188236                   5.586729
# 4          59982.19723             5.040555                   7.839388
# ...                ...                  ...                        ...
# 4995       60567.94414             7.830362                   6.137356
# 4996       78491.27543             6.999135                   6.576763
# 4997       63390.68689             7.250591                   4.805081
# 4998       68001.33124             5.534388                   7.130144
# 4999       65510.58180             5.992305                   6.792336
#
#       Avg. Area Number of Bedrooms  Area Population         Price  \
# ...

# %%
obj=df.select_dtypes(['object'])
obj
# Out:
#                                                 Address
# 0     208 Michael Ferry Apt. 674\nLaurabury, NE 3701...
# 1     188 Johnson Views Suite 079\nLake Kathleen, CA...
# 2     9127 Elizabeth Stravenue\nDanieltown, WI 06482...
# 3                             USS Barnett\nFPO AP 44820
# 4                            USNS Raymond\nFPO AE 09386
# ...                                                 ...
# 4995                   USNS Williams\nFPO AP 30153-7653
# 4996              PSC 9258, Box 8489\nAPO AA 42991-3352
# 4997  4215 Tracy Garden Suite 076\nJoshualand, VA 01...
# 4998                          USS Wallace\nFPO AE 73316
# 4999  37778 George Ridges Apt. 509\nEast Holly, NV 2...
#
# [5000 rows x 1 columns]

# %%
num=df.select_dtypes(['float64'])
num
# Out:
#       Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0          79545.45857             5.682861                   7.009188
# 1          79248.64245             6.002900                   6.730821
# 2          61287.06718             5.865890                   8.512727
# 3          63345.24005             7.188236                   5.586729
# 4          59982.19723             5.040555                   7.839388
# ...                ...                  ...                        ...
# 4995       60567.94414             7.830362                   6.137356
# 4996       78491.27543             6.999135                   6.576763
# 4997       63390.68689             7.250591                   4.805081
# 4998       68001.33124             5.534388                   7.130144
# 4999       65510.58180             5.992305                   6.792336
#
#       Avg. Area Number of Bedrooms  Area Population         Price
# ...

# %%
num.corr()
# Out:
#                               Avg. Area Income  Avg. Area House Age  \
# Avg. Area Income                      1.000000            -0.002007
# Avg. Area House Age                  -0.002007             1.000000
# Avg. Area Number of Rooms            -0.011032            -0.009428
# Avg. Area Number of Bedrooms          0.019788             0.006149
# Area Population                      -0.016234            -0.018743
# Price                                 0.639734             0.452543
#
#                               Avg. Area Number of Rooms  \
# Avg. Area Income                              -0.011032
# Avg. Area House Age                           -0.009428
# Avg. Area Number of Rooms                      1.000000
# Avg. Area Number of Bedrooms                   0.462695
# Area Population                                0.002040
# Price                                          0.335664
#
#                               Avg. Area Number of Bedrooms  Area Population  \
# ...

# %%
df.drop('Address', axis=1, inplace=True) # As address wans not contributing much towords identifying price hence dropped

# %%
df
# Out:
#       Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0          79545.45857             5.682861                   7.009188
# 1          79248.64245             6.002900                   6.730821
# 2          61287.06718             5.865890                   8.512727
# 3          63345.24005             7.188236                   5.586729
# 4          59982.19723             5.040555                   7.839388
# ...                ...                  ...                        ...
# 4995       60567.94414             7.830362                   6.137356
# 4996       78491.27543             6.999135                   6.576763
# 4997       63390.68689             7.250591                   4.805081
# 4998       68001.33124             5.534388                   7.130144
# 4999       65510.58180             5.992305                   6.792336
#
#       Avg. Area Number of Bedrooms  Area Population         Price
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
plt.figure(figsize = (6,6))
sns.boxplot(y=df['Price'])
plt.grid()
plt.grid(which = "minor")
plt.minorticks_on()
plt.show()

# %%
outlier= df[(df['Price']>=2150000) | (df['Price']<=300000)]
outlier_index = outlier.axes

outlier_row_index = outlier_index[0]
outlier_row_index
# Out:
# Index([  90,  126,  256,  263,  355,  437,  465,  622,  693,  696,  715,  901,
#         924,  990, 1141, 1195, 1208, 1248, 1271, 1356, 1459, 1485, 1516, 1536,
#        1578, 1661, 1799, 2017, 2300, 2538, 2719, 2756, 2795, 3064, 3091, 3212,
#        3502, 3922, 4129, 4375, 4400, 4451, 4855],
#       dtype='int64')

# %%
df.drop(outlier_row_index, inplace=True)

# %%
df
# Out:
#       Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0          79545.45857             5.682861                   7.009188
# 1          79248.64245             6.002900                   6.730821
# 2          61287.06718             5.865890                   8.512727
# 3          63345.24005             7.188236                   5.586729
# 4          59982.19723             5.040555                   7.839388
# ...                ...                  ...                        ...
# 4995       60567.94414             7.830362                   6.137356
# 4996       78491.27543             6.999135                   6.576763
# 4997       63390.68689             7.250591                   4.805081
# 4998       68001.33124             5.534388                   7.130144
# 4999       65510.58180             5.992305                   6.792336
#
#       Avg. Area Number of Bedrooms  Area Population         Price
# ...

# %%
plt.figure(figsize = (6,6))
sns.distplot(df["Price"])
plt.axvline(df["Price"].mean(),color = "blue", label = "Mean")
plt.axvline(df["Price"].median(),color = "yellow", label = "Median")
plt.legend()
plt.show()
# Out:
# C:\Users\MOHIT TARADE\AppData\Local\Temp\ipykernel_5444\4231196913.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["Price"])
# C:\Users\MOHIT TARADE\New folder\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
plt.figure(figsize = (6,6))
sns.heatmap(df.corr(), annot = True, cmap = "Pastel1", linecolor = "Green", linewidth = 2)
plt.show()

# %%
x=df.iloc[:,:-1]
x
# Out:
#       Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0          79545.45857             5.682861                   7.009188
# 1          79248.64245             6.002900                   6.730821
# 2          61287.06718             5.865890                   8.512727
# 3          63345.24005             7.188236                   5.586729
# 4          59982.19723             5.040555                   7.839388
# ...                ...                  ...                        ...
# 4995       60567.94414             7.830362                   6.137356
# 4996       78491.27543             6.999135                   6.576763
# 4997       63390.68689             7.250591                   4.805081
# 4998       68001.33124             5.534388                   7.130144
# 4999       65510.58180             5.992305                   6.792336
#
#       Avg. Area Number of Bedrooms  Area Population
# 0                             4.09      23086.80050
# ...

# %%
y=df['Price']
y
# Out:
# 0       1.059034e+06
# 1       1.505891e+06
# 2       1.058988e+06
# 3       1.260617e+06
# 4       6.309435e+05
#             ...
# 4995    1.060194e+06
# 4996    1.482618e+06
# 4997    1.030730e+06
# 4998    1.198657e+06
# 4999    1.298950e+06
# Name: Price, Length: 4957, dtype: float64

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
import warnings
warnings.filterwarnings("ignore")

# %%
for i in x:
    df[i]=sc.fit_transform(df[[i]])
x
# Out:
#       Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0          79545.45857             5.682861                   7.009188
# 1          79248.64245             6.002900                   6.730821
# 2          61287.06718             5.865890                   8.512727
# 3          63345.24005             7.188236                   5.586729
# 4          59982.19723             5.040555                   7.839388
# ...                ...                  ...                        ...
# 4995       60567.94414             7.830362                   6.137356
# 4996       78491.27543             6.999135                   6.576763
# 4997       63390.68689             7.250591                   4.805081
# 4998       68001.33124             5.534388                   7.130144
# 4999       65510.58180             5.992305                   6.792336
#
#       Avg. Area Number of Bedrooms  Area Population
# 0                             4.09      23086.80050
# ...

# %%
from sklearn.model_selection import train_test_split
xtrain, xtest, ytrain, ytest = train_test_split(x,y, test_size = 0.25, random_state = 0)

# %%
def mymodel(model):
    model.fit(xtrain,ytrain)
    ypred=model.predict(xtest)
    acc=r2_score(ytest,ypred)
    train=model.score(xtrain,ytrain)
    mse=mean_squared_error(ypred,ytest)
    rmse=np.sqrt(mse)
    print(f'accuracy={round(acc*100,2)}')
    print(f'Training acc={round(train*100,2)}')
    print(f'Tesing acc={rmse}')

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score, mean_squared_error
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR
from sklearn.ensemble import GradientBoostingRegressor, AdaBoostRegressor

from sklearn.ensemble import BaggingRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import accuracy_score, classification_report

# %%
lr = LinearRegression()
dt = DecisionTreeRegressor()
svm = SVR()
gbr = GradientBoostingRegressor()
ada = AdaBoostRegressor()
rfg = RandomForestRegressor()

# %%
mymodel(lr)
# Out:
# accuracy=90.83
# Training acc=91.41
# Tesing acc=103312.78099352695

# %%
mymodel(dt)
# Out:
# accuracy=72.66
# Training acc=100.0
# Tesing acc=178424.04584462757

# %%
# Max Depth

# %%
max_depth=[]
acc_list=[]
for i in range(1,30):
    dt1=DecisionTreeRegressor(max_depth=i)
    dt1.fit(xtrain,ytrain)
    ypred=dt1.predict(xtest)
    acc=r2_score(ytest,ypred)
    max_depth.append(i)
    acc_list.append(acc)
    print(f'max depth={i}, accuracy = {acc*100}')
# Out:
# max depth=1, accuracy = 26.54584189129071
# max depth=2, accuracy = 40.6830688151348
# max depth=3, accuracy = 52.33363199871518
# max depth=4, accuracy = 60.311499916482205
# max depth=5, accuracy = 65.95779184361204
# max depth=6, accuracy = 70.26666177099948
# max depth=7, accuracy = 73.9435956259747
# max depth=8, accuracy = 76.20221028520334
# max depth=9, accuracy = 75.70233306170799
# max depth=10, accuracy = 75.40997938259353
# max depth=11, accuracy = 75.19464542532506
# max depth=12, accuracy = 73.56423549732001
# max depth=13, accuracy = 73.34319651162552
# max depth=14, accuracy = 73.21450782053563
# max depth=15, accuracy = 72.71630681931995
# max depth=16, accuracy = 72.50155680261906
# max depth=17, accuracy = 72.45601102341426
# max depth=18, accuracy = 72.70185445552322
# max depth=19, accuracy = 72.13791866155816
# max depth=20, accuracy = 72.30637255862086
# max depth=21, accuracy = 73.05499504540214
# max depth=22, accuracy = 73.30853065496977
# ...

# %%
max_acc=acc_list[0]
for i in range(1,len(acc_list)):
    if (max_acc < acc_list[i]):
        max_acc=acc_list[i]
max_index=acc_list.index(max_acc)
print(f'max acc index = {max_index+1}')
# Out:
# max acc index = 8

# %%
dt2=DecisionTreeRegressor(max_depth=8)
mymodel(dt2)
# Out:
# accuracy=76.21
# Training acc=88.58
# Tesing acc=166422.35318725617

# %%
dt2.score(xtrain,ytrain)*100
# Out:
# 88.58291174205907

# %%
#Min sample Split

# %%
min_sample=[]
acc_list=[]
for i in range(2,50):
    dt3=DecisionTreeRegressor(min_samples_split=i)
    dt3.fit(xtrain,ytrain)
    ypred=dt3.predict(xtest)
    acc1=r2_score(ytest,ypred)
    min_sample.append(i)
    acc_list.append(acc1)
    print(f'Min saple split= {i}, acc = {acc1*100}')
# Out:
# Min saple split= 2, acc = 72.76647011462767
# Min saple split= 3, acc = 73.08716236461068
# Min saple split= 4, acc = 73.68585726496939
# Min saple split= 5, acc = 73.77196996470073
# Min saple split= 6, acc = 74.39840490312805
# Min saple split= 7, acc = 75.08666306727957
# Min saple split= 8, acc = 75.73225837487982
# Min saple split= 9, acc = 76.18105973237674
# Min saple split= 10, acc = 76.36362649896941
# Min saple split= 11, acc = 76.32182115597999
# Min saple split= 12, acc = 76.1942935539762
# Min saple split= 13, acc = 76.6182870122505
# Min saple split= 14, acc = 76.80814921060255
# Min saple split= 15, acc = 76.8430097746938
# Min saple split= 16, acc = 76.80290078139062
# Min saple split= 17, acc = 76.84978777807211
# Min saple split= 18, acc = 76.72348784479036
# Min saple split= 19, acc = 76.81772551250047
# Min saple split= 20, acc = 76.99813731836468
# Min saple split= 21, acc = 76.80425456683697
# Min saple split= 22, acc = 77.08520180197036
# ...

# %%
min_acc=acc_list[0]
for i in range(1, len(acc_list)):
    if (acc_list[i]>min_acc):
        min_acc=acc_list[i]
min_acc_index=acc_list.index(min_acc)
print(f'min acc index = {min_acc_index+2}')
# Out:
# min acc index = 27

# %%
dt4=DecisionTreeRegressor(min_samples_split=27)
mymodel(dt4)
# Out:
# accuracy=77.49
# Training acc=89.23
# Tesing acc=161884.67875976372

# %%
dt4.score(xtrain,ytrain)*100
# Out:
# 89.23101633670318

# %%
#To get best Mode using above DT models accuracy
dt5=DecisionTreeRegressor(max_depth=8,min_samples_split=27)
mymodel(dt5)
# Out:
# accuracy=75.74
# Training acc=86.47
# Tesing acc=168079.34524661337

# %%
# So according to accuracy above we can find that DT is not providing proper results so will proceed.

# %%
mymodel(svm)
# Out:
# accuracy=-0.24
# Training acc=0.03
# Tesing acc=341655.5995258776

# %%
param_grid = {'C':[1,10],'gamma':[1,10]}
gs = GridSearchCV(svm,param_grid,verbose=4)
gs.fit(xtrain,ytrain)
# Out:
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# [CV 1/5] END .....................C=1, gamma=1;, score=-0.000 total time=   1.6s
# [CV 2/5] END .....................C=1, gamma=1;, score=-0.005 total time=   1.6s
# [CV 3/5] END .....................C=1, gamma=1;, score=-0.002 total time=   1.6s
# [CV 4/5] END .....................C=1, gamma=1;, score=-0.001 total time=   1.7s
# [CV 5/5] END .....................C=1, gamma=1;, score=-0.000 total time=   1.4s
# [CV 1/5] END ....................C=1, gamma=10;, score=-0.000 total time=   1.8s
# [CV 2/5] END ....................C=1, gamma=10;, score=-0.005 total time=   1.5s
# [CV 3/5] END ....................C=1, gamma=10;, score=-0.002 total time=   1.7s
# [CV 4/5] END ....................C=1, gamma=10;, score=-0.001 total time=   1.7s
# [CV 5/5] END ....................C=1, gamma=10;, score=-0.000 total time=   1.5s
# [CV 1/5] END ....................C=10, gamma=1;, score=-0.000 total time=   1.6s
# ...

# %%
gs.best_params_
# Out:
# {'C': 1, 'gamma': 1}

# %%
svm1=SVR(C= 1, gamma= 10)
mymodel(svm1)
# Out:
# accuracy=-0.29
# Training acc=-0.02
# Tesing acc=341731.4182662941

# %%
mymodel(gbr)
# Out:
# accuracy=89.27
# Training acc=92.59
# Tesing acc=111768.320792962

# %%
mymodel(ada)
# Out:
# accuracy=82.3
# Training acc=83.63
# Tesing acc=143573.61102831367

# %%
#Conclusion: We will recommend to use linear model becuase it has the maximum accuracy(91.03%) and it is also good fit.

# %%
#input_data=[75000,10,12,5,45000]
#change data to numpy array
#id_numpy=np.array(input_data)
#reshape
#id_numpy_reshape=id_numpy.reshape(1,-1)
#print(id_numpy_reshape)

# %%
#prediction = lr.predict(id_numpy_reshape)
#print(prediction)

# %%
#if (prediction[0] == 0):
  #print(f'The expected price is -{Price}')

# %%
import pickle
filename='tm1.sav'
pickle.dump(lr,open(filename,'wb'))
loadedmodel=pickle.load(open('tm1.sav','rb'))
input_data=[55000,10,10,5,25000]
id_numpy=np.array(input_data)
id_numpy_reshape=id_numpy.reshape(1,-1)
prediction = loadedmodel.predict(id_numpy_reshape)
print(prediction)
if (prediction[0] == 0):
  print(f'The expected price is -{Price}')
# Out:
# [1806084.34257615]
